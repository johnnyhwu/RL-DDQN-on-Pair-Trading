# %% [markdown]
# ## Import Module

# %%
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Environment Class

# %%
class Environment:
    
    # constructor
    def __init__(self, company1, company2, price_col, training_dataset_ratio=0.8, nrm=1, one_episode_num_step=30):
        
        self.company1 = company1
        self.stock_price1 = None
        self.stock_price1_train = None
        self.stock_price1_test = None
        
        self.company2 = company2
        self.stock_price2 = None
        self.stock_price2_train = None
        self.stock_price2_test = None
        
        self.price_col = price_col
        self.stock_price_length = None
        
        self.training_dataset_ratio = training_dataset_ratio
        self.nrm = nrm
        
        self.stock_price_final = []
        self.local_current_step = None
        self.global_current_step = None
        self.purpose = None
        self.old_prupoese = None
        self.one_episode_num_step = one_episode_num_step
        
        # read two company's stock price
        self.load_data()
        
        # check if two stock price have same date-index
        
        
        # extract close price from two stock price and convert to numpy array
        self.extract_close_price()
        
        # split two stock close price into training set and testing set
        self.split_dataset()
        
    
    # read two company's stock price
    def load_data(self):
        
        try:
            self.stock_price1 = pd.read_csv(self.company1 + ".csv")
        except:
            raise Exception("Cannot load {}".format(self.company1 + ".csv"))
            
        try:
            self.stock_price2 = pd.read_csv(self.company2 + ".csv")
        except:
            raise Exception("Cannot load {}".format(self.company2 + ".csv"))
            
    
    # extract close price from two stock price and convert to numpy array
    def extract_close_price(self):
        
        try:
            self.stock_price1 = self.stock_price1[self.price_col]
            self.stock_price2 = self.stock_price2[self.price_col]
        except:
            raise Exception("Cannot extract stock price column: {}.".format(self.price_col))
            
        
        self.stock_price1 = self.stock_price1.values
        self.stock_price2 = self.stock_price2.values
        self.stock_price_length = len(self.stock_price1)
        
        
    # split two stock close price into training set and testing set
    def split_dataset(self):
        
        index = round(self.stock_price_length * self.training_dataset_ratio)
        
        self.stock_price1_train = self.stock_price1[:index]
        self.stock_price1_test = self.stock_price1[index:]
        
        self.stock_price2_train = self.stock_price2[:index]
        self.stock_price2_test = self.stock_price2[index:]
        
        print("===============Environment Info===============")
        print("Stock1: {}".format(self.company1))
        print("Stock2: {}".format(self.company2))
        print("Price Column: {}".format(self.price_col))
        print("Ngative Return Multiplier: {}".format(self.nrm))
        print("Total number of day for training: {}".format(str(len(self.stock_price1_train))))
        print("Total number of day for testing: {}".format(str(len(self.stock_price1_test))))
        print("==============================================")
        
    
    # reset environment: must specify purpose for training or tetsing
    def reset(self, purpose):
        
        self.purpose = purpose
        
        if self.purpose != self.old_prupoese:
            self.prepare_final_data()
            self.old_prupoese = self.purpose
            self.global_current_step = 0
        
        self.global_current_step += 1
        self.local_current_step = 0
        
        
        if self.global_current_step == len(self.stock_price_final)-self.one_episode_num_step+1:
            self.global_current_step = 0
            
        return self.stock_price_final[self.global_current_step]
            
            
    # prepare train data
    def prepare_final_data(self):
        
        # spread of two stock
        if self.purpose == "train":
            spread = self.stock_price1_train - self.stock_price2_train
        else:
            spread = self.stock_price1_test - self.stock_price2_test
        
        
        for idx, value in enumerate(spread[:-1]):
            
            one_step = np.empty(shape=(10))
            one_step_idx = 0
            
            # current spread
            current_spread = value
            one_step[one_step_idx] = current_spread
            one_step_idx += 1
            
            # daily return of spread
            daily_return_spread = spread[idx+1] - current_spread
            one_step[one_step_idx] = daily_return_spread
            one_step_idx += 1
            
            # spread mean during past 15 days
            if idx != 0:
                temp_idx = 0 if (idx-15<0) else (idx-15)
                spread_mean_15_days = np.mean(spread[temp_idx:idx])
            else:
                spread_mean_15_days = value
            
            one_step[one_step_idx] = spread_mean_15_days
            one_step_idx += 1
            
            # curren spread / spread mean during past 15 days
            one_step[one_step_idx] = current_spread / spread_mean_15_days
            one_step_idx += 1
            
            # spread mean during past 10 days
            if idx != 0:
                temp_idx = 0 if (idx-10<0) else (idx-10)
                spread_mean_10_days = np.mean(spread[temp_idx:idx])
            else:
                spread_mean_10_days = value
            one_step[one_step_idx] = spread_mean_10_days
            one_step_idx += 1
            
            # curren spread / spread mean during past 10 days
            one_step[one_step_idx] = current_spread / spread_mean_10_days
            one_step_idx += 1
            
            # spread mean during past 7 days
            if idx != 0:
                temp_idx = 0 if (idx-7<0) else (idx-7)
                spread_mean_7_days = np.mean(spread[temp_idx:idx])
            else:
                spread_mean_7_days = value
            one_step[one_step_idx] = spread_mean_7_days
            one_step_idx += 1
            
            # curren spread / spread mean during past 7 days
            one_step[one_step_idx] = current_spread / spread_mean_7_days
            one_step_idx += 1
            
            # spread mean during past 5 days
            if idx != 0:
                temp_idx = 0 if (idx-5<0) else (idx-5)
                spread_mean_5_days = np.mean(spread[temp_idx:idx])
            else:
                spread_mean_5_days = value
            one_step[one_step_idx] = spread_mean_5_days
            one_step_idx += 1
            
            # curren spread / spread mean during past 5 days
            one_step[one_step_idx] = current_spread / spread_mean_5_days
            one_step_idx += 1
            
            self.stock_price_final.append(one_step)
            
    
    # go next step: must provide action
    def step(self, action):
        
        # new state
        self.local_current_step += 1
        step_idx = self.global_current_step + self.local_current_step
        new_state = self.stock_price_final[step_idx]
        
        # reward
        reward = action * self.stock_price_final[step_idx-1][1]
        if self.purpose == "train":
            reward = reward * self.nrm if reward < 0 else reward
            
        # is done
        done = True if((self.local_current_step == self.one_episode_num_step-1) or (step_idx==len(self.stock_price_final)-1)) else False
        
        return new_state, reward, done

# %% [markdown]
# ## Agent Class

# %%
class Agent:
    
    # constructor
    def __init__(self, 
                 state_dim,
                 action_dim,
                 learning_rate,
                 exploration_rate, 
                 exploration_decay,
                 exploration_min, 
                 replay_buffer_size,
                 batch_size, 
                 q_value_discounter
                ):
        
        # state dimension
        self.state_dim = state_dim
        
        # action dimension
        self.action_dim = action_dim
        
        # learning rate
        self.learning_rate = learning_rate
        
        # exploration rate, decay and min for agent
        self.exploration_rate = exploration_rate
        self.exploration_decay = exploration_decay
        self.exploration_min = exploration_min
        
        # replay buffer size, batch size for agent
        self.replay_buffer_size = replay_buffer_size
        self.batch_size = batch_size
        
        # replay_buffer will store: state1, action1, reward1, state2, done1
        self.replay_buffer = np.empty((self.replay_buffer_size, 10+1+1+10+1))
        self.replay_buffer_counter = 0
        
        # discounter of max q value among actions 
        self.q_value_discounter = q_value_discounter
        
        # build update_critic and target_critic
        self.update_critic = self.build_nn(name="Update_Critic")
        self.update_critic.summary()
        self.target_critic = self.build_nn(name="Target_Critic")
        self.target_critic.summary()
        
        
    
    # build a neural network as critic
    def build_nn(self, name):
        
        inputs = keras.Input(shape=(self.state_dim), name="InputLayer")
        hidden1 = keras.layers.Dense(20, activation="relu", name="HiddenLayer1")(inputs)
        hidden2 = keras.layers.Dense(10, activation="relu", name="HiddenLayer2")(hidden1)
        outputs = keras.layers.Dense(3, activation="linear", name="OutputLayer")(hidden2)
        
        model = keras.Model(inputs=inputs, outputs=outputs, name=name)
        model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=self.learning_rate))
        
        return model
    

    # smaple action given a state
    def sample_action(self, state):
        
        explore = np.random.uniform(low=0.0, high=1.0)
        
        # explore
        if explore < self.exploration_rate:
            action_index = np.random.choice(self.action_dim)
        
        else:
            state = np.reshape(state, (1, self.state_dim))
            action = self.update_critic.predict(state)[0]
            action_index = np.argmax(action)
        
        # action should be: 0, 1, -1
        action_index -= 1
        
        return action_index
        
        
    # store experience into replay buffer
    def store_experience(self, state1, action1, reward1, state2, done1):
        
        experience = np.empty((10+1+1+10+1))
        experience[0:10] = state1[:]
        experience[10] = action1
        experience[11] = reward1
        experience[12:22] = state2[:]
        experience[22] = int(done1)
        
        self.replay_buffer[self.replay_buffer_counter % self.replay_buffer_size][:] = experience
        self.replay_buffer_counter += 1
        
    
    # update target_critic by copying update_critic'weight to target_critic
    def update_target_critic(self):
        
        self.target_critic.set_weights(self.update_critic.get_weights())
        
        
    # train critic with experience from replay buffer
    def train(self):
        
        if self.replay_buffer_counter < self.batch_size:
            return
        
        # sample batch of experience from replay buffer
        low_idx = 0
        high_idx = min(self.replay_buffer_counter, self.replay_buffer_size)
        mask = np.random.randint(low=low_idx, high=high_idx, size=self.batch_size)
        batch_experience = self.replay_buffer[mask][:]
        
        # each experience: state1, action1, reward1, state2, done1
        for experience in batch_experience:
            
            state1 = experience[0:10]
            action1 = experience[10]
            reward1 = experience[11]
            state2 = experience[12:22]
            done1 = experience[22]
            
            # if state2 is final state in its episode
            if done1 == 1:
                target_reward = reward1
            
            # if not
            else:
                
                # select action by update_critic
                state = np.reshape(state2, (1, self.state_dim))
                action_idx = np.argmax(self.update_critic.predict(state)[0])
                
                # estimate q value by target critic
                target_reward = reward1 + self.q_value_discounter * self.target_critic.predict(state)[0][action_idx]
            
            state = np.reshape(state1, (1, self.state_dim))
            action_value = self.update_critic.predict(state)
            action_value[0][int(action1+1)] = target_reward
            
            self.update_critic.fit(x=state, y=action_value, verbose=0)
            
        
        # update target_critic
        self.update_target_critic()
                
        
        # decrease exploraction rate
        self.exploration_rate = max(self.exploration_min, self.exploration_rate*self.exploration_decay)

# %% [markdown]
# ## PairTrading Class

# %%
class PairTrading:
    
    # constructor
    def __init__(self):
        
        # state dimension 
        state_dim = 10
        
        # action dimension
        action_dim = 3
        
        # learning rate for agent
        learning_rate = 0.001
        
        # exploration rate, decay and min for agent
        exploration_rate = 1
        exploration_decay = 0.995
        exploration_min = 0.01
        
        # replay buffer size, batch size for agent
        replay_buffer_size = 500
        batch_size = 50
        
        # discounter of max q value among actions 
        q_value_discounter = 0.95
        
        # build agent
        self.agent = Agent(state_dim=state_dim,
                           action_dim=action_dim,
                           learning_rate=learning_rate,
                           exploration_rate=exploration_rate,
                           exploration_decay=exploration_decay,
                           exploration_min=exploration_min,
                           replay_buffer_size=replay_buffer_size,
                           batch_size=batch_size,
                           q_value_discounter=q_value_discounter
                           )
        
        # build environment
        self.env = Environment(company1="AAPL",
                               company2="GOOG", 
                               price_col="Close",
                               training_dataset_ratio=0.99,
                               nrm=500,
                               one_episode_num_step=40)
        
        # total episode to play
        self.total_episode = 1000
        
        # store every episode's total reward
        self.episode_total_reward = []
        
        
    # start to play pair trading
    def start(self):
        
        for episode in range(self.total_episode):
            
            # total rewardin each episode
            total_reward = 0
            
            # a flag to indicate if the episode ends
            done = False
            
            # get environment's initial state
            state1 = self.env.reset(purpose="train")
            
            while done is False:
                
                # agent samples an action given state
                action1 = self.agent.sample_action(state1)
                
                # environemnt enters next state given action
                state2, reward1, done1 = self.env.step(action1)
                
                # store this step (experience)
                self.agent.store_experience(state1, action1, reward1, state2, done1)
                
                # update local variable
                state1 = state2
                done = done1
                total_reward += reward1
                
            # when this episode ends...
            print("#%.3d Episode's Reward: %.4d" %(episode, total_reward))
            self.episode_total_reward.append(total_reward)
            self.agent.train()
            
    def plot_result(self):
        
        x = list(range(0, self.total_episode))
        y = self.episode_total_reward
        plt.plot(x, y, color="blue", label="nrm={}".format(str(self.env.nrm)))
        plt.xlabel("Episode")
        plt.ylabel("Total Reward")
        plt.title("DDQN Agent's Performance on Pair Trading")
        plt.legend(loc="upper left")
        plt.savefig("{}.png".format(str(self.env.nrm)))
        plt.show()

# %% [markdown]
# ## Main

# %%
pair_trading_game = PairTrading()
pair_trading_game.start()
pair_trading_game.plot_result()
# Out:
# Model: "Update_Critic"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# InputLayer (InputLayer)      [(None, 10)]              0
# _________________________________________________________________
# HiddenLayer1 (Dense)         (None, 20)                220
# _________________________________________________________________
# HiddenLayer2 (Dense)         (None, 10)                210
# _________________________________________________________________
# OutputLayer (Dense)          (None, 3)                 33
# =================================================================
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________
# Model: "Target_Critic"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# InputLayer (InputLayer)      [(None, 10)]              0
# _________________________________________________________________
# HiddenLayer1 (Dense)         (None, 20)                220
# _________________________________________________________________
# HiddenLayer2 (Dense)         (None, 10)                210
# _________________________________________________________________
# OutputLayer (Dense)          (None, 3)                 33
# =================================================================
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________
# ===============Environment Info===============
# Stock1: AAPL
# Stock2: GOOG
# Price Column: Close
# Ngative Return Multiplier: 500
# Total number of day for training: 1245
# Total number of day for testing: 13
# ==============================================
# #000 Episode's Reward: -18894
# #001 Episode's Reward: -14334
# #002 Episode's Reward: -20344
# #003 Episode's Reward: -17540
# #004 Episode's Reward: -17595
# #005 Episode's Reward: -27782
# #006 Episode's Reward: -35290
# #007 Episode's Reward: -20911
# #008 Episode's Reward: -37499
# #009 Episode's Reward: -33753
# #010 Episode's Reward: -21884
# #011 Episode's Reward: -29995
# #012 Episode's Reward: -27397
# #013 Episode's Reward: -22605
# #014 Episode's Reward: -12314
# #015 Episode's Reward: -32985
# #016 Episode's Reward: -25809
# #017 Episode's Reward: -11950
# #018 Episode's Reward: -21193
# #019 Episode's Reward: -12379
# #020 Episode's Reward: -25083
# #021 Episode's Reward: -24721
# #022 Episode's Reward: -43520
# #023 Episode's Reward: -6264
# #024 Episode's Reward: -10847
# #025 Episode's Reward: -15699
# #026 Episode's Reward: -13358
# #027 Episode's Reward: -18281
# #028 Episode's Reward: -12241
# #029 Episode's Reward: -11657
# #030 Episode's Reward: -10183
# #031 Episode's Reward: -12508
# #032 Episode's Reward: -22890
# #033 Episode's Reward: -11905
# #034 Episode's Reward: -10384
# #035 Episode's Reward: -12566
# #036 Episode's Reward: -15362
# #037 Episode's Reward: -12237
# #038 Episode's Reward: -19774
# #039 Episode's Reward: -16052
# #040 Episode's Reward: -17528
# #041 Episode's Reward: -11078
# #042 Episode's Reward: -21953
# #043 Episode's Reward: -14098
# #044 Episode's Reward: -14226
# #045 Episode's Reward: -17992
# #046 Episode's Reward: -11285
# #047 Episode's Reward: -9933
# #048 Episode's Reward: -18108
# #049 Episode's Reward: -10857
# #050 Episode's Reward: -10984
# #051 Episode's Reward: -16572
# #052 Episode's Reward: -16048
# #053 Episode's Reward: -25183
# #054 Episode's Reward: -18281
# #055 Episode's Reward: -15807
# #056 Episode's Reward: -20814
# #057 Episode's Reward: -22582
# #058 Episode's Reward: -11943
# #059 Episode's Reward: -2365
# #060 Episode's Reward: -26515
# #061 Episode's Reward: -9457
# #062 Episode's Reward: -8278
# #063 Episode's Reward: -33978
# #064 Episode's Reward: -12378
# #065 Episode's Reward: -22007
# #066 Episode's Reward: -26755
# #067 Episode's Reward: -18684
# #068 Episode's Reward: -19140
# #069 Episode's Reward: -9547
# #070 Episode's Reward: -20930
# #071 Episode's Reward: -24105
# #072 Episode's Reward: -9288
# #073 Episode's Reward: -17303
# #074 Episode's Reward: -4497
# #075 Episode's Reward: -22964
# #076 Episode's Reward: -11894
# #077 Episode's Reward: -9049
# #078 Episode's Reward: -16621
# #079 Episode's Reward: -17317
# #080 Episode's Reward: -17201
# #081 Episode's Reward: -11986
# #082 Episode's Reward: -19734
# #083 Episode's Reward: -16694
# #084 Episode's Reward: -6732
# #085 Episode's Reward: -15394
# #086 Episode's Reward: -27959
# #087 Episode's Reward: -4276
# #088 Episode's Reward: -19079
# #089 Episode's Reward: -6938
# #090 Episode's Reward: -24942
# #091 Episode's Reward: -12535
# #092 Episode's Reward: -9186
# #093 Episode's Reward: -15578
# #094 Episode's Reward: -4623
# #095 Episode's Reward: -4351
# #096 Episode's Reward: -16398
# #097 Episode's Reward: -9946
# #098 Episode's Reward: -10660
# #099 Episode's Reward: -14573
# #100 Episode's Reward: -13795
# #101 Episode's Reward: -9039
# #102 Episode's Reward: -14124
# #103 Episode's Reward: -9135
# #104 Episode's Reward: -7241
# #105 Episode's Reward: -12221
# #106 Episode's Reward: -13412
# #107 Episode's Reward: -18266
# #108 Episode's Reward: -10871
# #109 Episode's Reward: -11282
# #110 Episode's Reward: -21107
# #111 Episode's Reward: -11928
# #112 Episode's Reward: -17589
# #113 Episode's Reward: -11454
# #114 Episode's Reward: -16936
# #115 Episode's Reward: -5010
# #116 Episode's Reward: -5639
# #117 Episode's Reward: -16761
# #118 Episode's Reward: -22866
# #119 Episode's Reward: -16418
# #120 Episode's Reward: -16060
# #121 Episode's Reward: -16185
# #122 Episode's Reward: -16320
# #123 Episode's Reward: -23380
# #124 Episode's Reward: -7222
# #125 Episode's Reward: -12007
# #126 Episode's Reward: -7062
# #127 Episode's Reward: -27384
# #128 Episode's Reward: -21161
# #129 Episode's Reward: -6745
# #130 Episode's Reward: -10587
# #131 Episode's Reward: -20827
# #132 Episode's Reward: -6972
# #133 Episode's Reward: -10460
# #134 Episode's Reward: -8252
# #135 Episode's Reward: -12670
# #136 Episode's Reward: -14148
# #137 Episode's Reward: -21351
# #138 Episode's Reward: -8137
# #139 Episode's Reward: -15105
# #140 Episode's Reward: -13976
# #141 Episode's Reward: -24844
# #142 Episode's Reward: -3197
# #143 Episode's Reward: -2447
# #144 Episode's Reward: -4972
# #145 Episode's Reward: -18215
# #146 Episode's Reward: -23721
# #147 Episode's Reward: -23992
# #148 Episode's Reward: -6613
# #149 Episode's Reward: -7938
# #150 Episode's Reward: -14347
# #151 Episode's Reward: -7915
# #152 Episode's Reward: -6813
# #153 Episode's Reward: -10181
# #154 Episode's Reward: -13353
# #155 Episode's Reward: -17930
# #156 Episode's Reward: -6680
# #157 Episode's Reward: -11723
# #158 Episode's Reward: -0821
# #159 Episode's Reward: -13102
# #160 Episode's Reward: -18295
# #161 Episode's Reward: -4105
# #162 Episode's Reward: -12682
# #163 Episode's Reward: -12101
# #164 Episode's Reward: -1687
# #165 Episode's Reward: -17905
# #166 Episode's Reward: -16323
# #167 Episode's Reward: -7767
# #168 Episode's Reward: -17839
# #169 Episode's Reward: -14732
# #170 Episode's Reward: -7421
# #171 Episode's Reward: -16160
# #172 Episode's Reward: -12955
# #173 Episode's Reward: -8810
# #174 Episode's Reward: -12867
# #175 Episode's Reward: -6723
# #176 Episode's Reward: -9702
# #177 Episode's Reward: -3854
# #178 Episode's Reward: -8510
# #179 Episode's Reward: -13872
# #180 Episode's Reward: -11709
# #181 Episode's Reward: -7074
# #182 Episode's Reward: -3615
# #183 Episode's Reward: -9931
# #184 Episode's Reward: -13252
# #185 Episode's Reward: -13145
# #186 Episode's Reward: -10946
# #187 Episode's Reward: -9867
# #188 Episode's Reward: -8873
# #189 Episode's Reward: -2039
# #190 Episode's Reward: -6546
# #191 Episode's Reward: -8292
# #192 Episode's Reward: -22593
# #193 Episode's Reward: -9480
# #194 Episode's Reward: -7861
# #195 Episode's Reward: -6712
# #196 Episode's Reward: -11102
# #197 Episode's Reward: -13793
# #198 Episode's Reward: -6554
# #199 Episode's Reward: -8457
# #200 Episode's Reward: -3358
# #201 Episode's Reward: -11789
# #202 Episode's Reward: -6253
# #203 Episode's Reward: -4091
# #204 Episode's Reward: -3997
# #205 Episode's Reward: -7389
# #206 Episode's Reward: -9431
# #207 Episode's Reward: -11289
# #208 Episode's Reward: -3361
# #209 Episode's Reward: -4449
# #210 Episode's Reward: -3942
# #211 Episode's Reward: -6919
# #212 Episode's Reward: -11797
# #213 Episode's Reward: -14888
# #214 Episode's Reward: -4705
# #215 Episode's Reward: -3970
# #216 Episode's Reward: -5495
# #217 Episode's Reward: -1074
# #218 Episode's Reward: -1796
# #219 Episode's Reward: -1458
# #220 Episode's Reward: -9372
# #221 Episode's Reward: -12018
# #222 Episode's Reward: -7375
# #223 Episode's Reward: -12828
# #224 Episode's Reward: -3694
# #225 Episode's Reward: -6244
# #226 Episode's Reward: -9237
# #227 Episode's Reward: -9291
# #228 Episode's Reward: -2638
# #229 Episode's Reward: -3590
# #230 Episode's Reward: -4590
# #231 Episode's Reward: -9205
# #232 Episode's Reward: -7564
# #233 Episode's Reward: -8652
# #234 Episode's Reward: -3304
# #235 Episode's Reward: -4353
# #236 Episode's Reward: -11951
# #237 Episode's Reward: -5328
# #238 Episode's Reward: -0886
# #239 Episode's Reward: -11571
# #240 Episode's Reward: -2501
# #241 Episode's Reward: -3603
# #242 Episode's Reward: -9461
# #243 Episode's Reward: -7751
# #244 Episode's Reward: -2503
# #245 Episode's Reward: -8879
# #246 Episode's Reward: -9187
# #247 Episode's Reward: -7864
# #248 Episode's Reward: 0073
# #249 Episode's Reward: -11438
# #250 Episode's Reward: -10964
# #251 Episode's Reward: -0486
# #252 Episode's Reward: -8989
# #253 Episode's Reward: -2473
# #254 Episode's Reward: -0617
# #255 Episode's Reward: 0004
# #256 Episode's Reward: -4186
# #257 Episode's Reward: -4473
# #258 Episode's Reward: -38517
# #259 Episode's Reward: -5799
# #260 Episode's Reward: -7682
# #261 Episode's Reward: -2461
# #262 Episode's Reward: -11483
# #263 Episode's Reward: -3266
# #264 Episode's Reward: -1952
# #265 Episode's Reward: -4113
# #266 Episode's Reward: -7009
# #267 Episode's Reward: -7110
# #268 Episode's Reward: -2483
# #269 Episode's Reward: -6084
# #270 Episode's Reward: -5046
# #271 Episode's Reward: -3566
# #272 Episode's Reward: -8647
# #273 Episode's Reward: -1039
# #274 Episode's Reward: -3814
# #275 Episode's Reward: -11532
# #276 Episode's Reward: -8034
# #277 Episode's Reward: -33402
# #278 Episode's Reward: -5585
# #279 Episode's Reward: -3537
# #280 Episode's Reward: -12917
# #281 Episode's Reward: -3265
# #282 Episode's Reward: -0143
# #283 Episode's Reward: -8651
# #284 Episode's Reward: -6185
# #285 Episode's Reward: -5122
# #286 Episode's Reward: -5868
# #287 Episode's Reward: -8422
# #288 Episode's Reward: 0018
# #289 Episode's Reward: -3489
# #290 Episode's Reward: -9292
# #291 Episode's Reward: 0017
# #292 Episode's Reward: -1629
# #293 Episode's Reward: -4355
# #294 Episode's Reward: -2107
# #295 Episode's Reward: -4179
# #296 Episode's Reward: -11476
# #297 Episode's Reward: -6711
# #298 Episode's Reward: -9629
# #299 Episode's Reward: -6958
# #300 Episode's Reward: -5082
# #301 Episode's Reward: -9629
# #302 Episode's Reward: -5575
# #303 Episode's Reward: -1820
# #304 Episode's Reward: 0021
# #305 Episode's Reward: -4781
# #306 Episode's Reward: -4632
# #307 Episode's Reward: -6968
# #308 Episode's Reward: -2129
# #309 Episode's Reward: -2691
# #310 Episode's Reward: -6860
# #311 Episode's Reward: -6747
# #312 Episode's Reward: -19456
# #313 Episode's Reward: -4743
# #314 Episode's Reward: -3368
# #315 Episode's Reward: -16751
# #316 Episode's Reward: -14275
# #317 Episode's Reward: -10116
# #318 Episode's Reward: -16229
# #319 Episode's Reward: -20804
# #320 Episode's Reward: -2084
# #321 Episode's Reward: -8012
# #322 Episode's Reward: -19700
# #323 Episode's Reward: 0062
# #324 Episode's Reward: -3825
# #325 Episode's Reward: -0124
# #326 Episode's Reward: -1987
# #327 Episode's Reward: -15036
# #328 Episode's Reward: -12276
# #329 Episode's Reward: -13132
# #330 Episode's Reward: -20243
# #331 Episode's Reward: 0041
# #332 Episode's Reward: -16530
# #333 Episode's Reward: -2562
# #334 Episode's Reward: 0008
# #335 Episode's Reward: -18705
# #336 Episode's Reward: 0022
# #337 Episode's Reward: -11473
# #338 Episode's Reward: -7440
# #339 Episode's Reward: -14770
# #340 Episode's Reward: -1508
# #341 Episode's Reward: 0019
# #342 Episode's Reward: -15279
# #343 Episode's Reward: -13840
# #344 Episode's Reward: -8547
# #345 Episode's Reward: -13395
# #346 Episode's Reward: -12548
# #347 Episode's Reward: -3820
# #348 Episode's Reward: 0007
# #349 Episode's Reward: -13972
# #350 Episode's Reward: -4431
# #351 Episode's Reward: -28021
# #352 Episode's Reward: -4649
# #353 Episode's Reward: 0000
# #354 Episode's Reward: -0805
# #355 Episode's Reward: -9519
# #356 Episode's Reward: -0315
# #357 Episode's Reward: -3681
# #358 Episode's Reward: -5819
# #359 Episode's Reward: -12764
# #360 Episode's Reward: -7489
# #361 Episode's Reward: -0209
# #362 Episode's Reward: -18297
# #363 Episode's Reward: -14804
# #364 Episode's Reward: -10939
# #365 Episode's Reward: -4104
# #366 Episode's Reward: -9957
# #367 Episode's Reward: -6093
# #368 Episode's Reward: -7104
# #369 Episode's Reward: -6159
# #370 Episode's Reward: -0144
# #371 Episode's Reward: -2784
# #372 Episode's Reward: -0311
# #373 Episode's Reward: -4904
# #374 Episode's Reward: -5087
# #375 Episode's Reward: -4775
# #376 Episode's Reward: -12984
# #377 Episode's Reward: -10074
# #378 Episode's Reward: -9703
# #379 Episode's Reward: -12412
# #380 Episode's Reward: -0781
# #381 Episode's Reward: -4377
# #382 Episode's Reward: -3077
# #383 Episode's Reward: -13090
# #384 Episode's Reward: -3811
# #385 Episode's Reward: -10316
# #386 Episode's Reward: -2211
# #387 Episode's Reward: -17259
# #388 Episode's Reward: 0000
# #389 Episode's Reward: -16130
# #390 Episode's Reward: -2214
# #391 Episode's Reward: -2239
# #392 Episode's Reward: -3396
# #393 Episode's Reward: -9611
# #394 Episode's Reward: 0003
# #395 Episode's Reward: -17872
# #396 Episode's Reward: -3004
# #397 Episode's Reward: -9924
# #398 Episode's Reward: -2364
# #399 Episode's Reward: -5962
# #400 Episode's Reward: -10399
# #401 Episode's Reward: -10615
# #402 Episode's Reward: -3718
# #403 Episode's Reward: -1976
# #404 Episode's Reward: -5365
# #405 Episode's Reward: -9362
# #406 Episode's Reward: -3318
# #407 Episode's Reward: -0789
# #408 Episode's Reward: 0000
# #409 Episode's Reward: -1514
# #410 Episode's Reward: -15216
# #411 Episode's Reward: -7861
# #412 Episode's Reward: -3219
# #413 Episode's Reward: -3593
# #414 Episode's Reward: -0073
# #415 Episode's Reward: -15174
# #416 Episode's Reward: 0001
# #417 Episode's Reward: -0564
# #418 Episode's Reward: -0900
# #419 Episode's Reward: 0001
# #420 Episode's Reward: -10002
# #421 Episode's Reward: -4861
# #422 Episode's Reward: -1589
# #423 Episode's Reward: -7219
# #424 Episode's Reward: -14365
# #425 Episode's Reward: -10290
# #426 Episode's Reward: -2574
# #427 Episode's Reward: -2992
# #428 Episode's Reward: -0144
# #429 Episode's Reward: 0000
# #430 Episode's Reward: -0070
# #431 Episode's Reward: -0147
# #432 Episode's Reward: -2147
# #433 Episode's Reward: -11764
# #434 Episode's Reward: -1799
# #435 Episode's Reward: -13476
# #436 Episode's Reward: 0004
# #437 Episode's Reward: 0017
# #438 Episode's Reward: 0005
# #439 Episode's Reward: -7582
# #440 Episode's Reward: -6954
# #441 Episode's Reward: 0008
# #442 Episode's Reward: -0616
# #443 Episode's Reward: -0707
# #444 Episode's Reward: -8831
# #445 Episode's Reward: -2552
# #446 Episode's Reward: -7591
# #447 Episode's Reward: -2468
# #448 Episode's Reward: -2152
# #449 Episode's Reward: -3782
# #450 Episode's Reward: 0005
# #451 Episode's Reward: -6608
# #452 Episode's Reward: 0000
# #453 Episode's Reward: -1062
# #454 Episode's Reward: -4022
# #455 Episode's Reward: -6411
# #456 Episode's Reward: 0001
# #457 Episode's Reward: -7541
# #458 Episode's Reward: 0023
# #459 Episode's Reward: 0002
# #460 Episode's Reward: 0004
# #461 Episode's Reward: -4747
# #462 Episode's Reward: 0006
# #463 Episode's Reward: -2546
# #464 Episode's Reward: -0112
# #465 Episode's Reward: -4040
# #466 Episode's Reward: 0008
# #467 Episode's Reward: 0010
# #468 Episode's Reward: -6094
# #469 Episode's Reward: 0010
# #470 Episode's Reward: 0000
# #471 Episode's Reward: -2882
# #472 Episode's Reward: -6613
# #473 Episode's Reward: -11469
# #474 Episode's Reward: -0771
# #475 Episode's Reward: -0818
# #476 Episode's Reward: -10257
# #477 Episode's Reward: -5479
# #478 Episode's Reward: -4025
# #479 Episode's Reward: -4507
# #480 Episode's Reward: -2127
# #481 Episode's Reward: -9618
# #482 Episode's Reward: -1286
# #483 Episode's Reward: -5358
# #484 Episode's Reward: -3789
# #485 Episode's Reward: -1596
# #486 Episode's Reward: -2929
# #487 Episode's Reward: -4990
# #488 Episode's Reward: -4507
# #489 Episode's Reward: -9090
# #490 Episode's Reward: -4030
# #491 Episode's Reward: -4150
# #492 Episode's Reward: -4153
# #493 Episode's Reward: 0013
# #494 Episode's Reward: 0000
# #495 Episode's Reward: -2043
# #496 Episode's Reward: -3806
# #497 Episode's Reward: -7849
# #498 Episode's Reward: -2131
# #499 Episode's Reward: 0018
# #500 Episode's Reward: -2972
# #501 Episode's Reward: -4699
# #502 Episode's Reward: -0169
# #503 Episode's Reward: -2732
# #504 Episode's Reward: -5164
# #505 Episode's Reward: 0029
# #506 Episode's Reward: -4544
# #507 Episode's Reward: -3763
# #508 Episode's Reward: -4377
# #509 Episode's Reward: -0645
# #510 Episode's Reward: -6520
# #511 Episode's Reward: -7356
# #512 Episode's Reward: -1509
# #513 Episode's Reward: -4699
# #514 Episode's Reward: -4971
# #515 Episode's Reward: 0000
# #516 Episode's Reward: 0000
# #517 Episode's Reward: -3838
# #518 Episode's Reward: 0000
# #519 Episode's Reward: -2260
# #520 Episode's Reward: -7554
# #521 Episode's Reward: -7823
# #522 Episode's Reward: -0197
# #523 Episode's Reward: -5398
# #524 Episode's Reward: 0001
# #525 Episode's Reward: -0664
# #526 Episode's Reward: -4746
# #527 Episode's Reward: -2062
# #528 Episode's Reward: 0000
# #529 Episode's Reward: 0000
# #530 Episode's Reward: -0762
# #531 Episode's Reward: -1414
# #532 Episode's Reward: -6715
# #533 Episode's Reward: 0007
# #534 Episode's Reward: 0002
# #535 Episode's Reward: 0003
# #536 Episode's Reward: -1894
# #537 Episode's Reward: 0004
# #538 Episode's Reward: -4213
# #539 Episode's Reward: -1861
# #540 Episode's Reward: -4203
# #541 Episode's Reward: -1100
# #542 Episode's Reward: 0000
# #543 Episode's Reward: 0000
# #544 Episode's Reward: 0002
# #545 Episode's Reward: 0000
# #546 Episode's Reward: 0000
# #547 Episode's Reward: 0000
# #548 Episode's Reward: -2156
# #549 Episode's Reward: -5936
# #550 Episode's Reward: 0002
# #551 Episode's Reward: -4350
# #552 Episode's Reward: -3052
# #553 Episode's Reward: 0020
# #554 Episode's Reward: -0930
# #555 Episode's Reward: -1054
# #556 Episode's Reward: -1173
# #557 Episode's Reward: 0000
# #558 Episode's Reward: -3034
# #559 Episode's Reward: -0184
# #560 Episode's Reward: 0000
# #561 Episode's Reward: 0003
# #562 Episode's Reward: 0002
# #563 Episode's Reward: 0000
# #564 Episode's Reward: -5830
# #565 Episode's Reward: -3052
# #566 Episode's Reward: -2403
# #567 Episode's Reward: -3668
# #568 Episode's Reward: -1466
# #569 Episode's Reward: -12767
# #570 Episode's Reward: -12767
# #571 Episode's Reward: 0014
# #572 Episode's Reward: 0000
# #573 Episode's Reward: -3746
# #574 Episode's Reward: -1461
# #575 Episode's Reward: 0000
# #576 Episode's Reward: -3915
# #577 Episode's Reward: -5070
# #578 Episode's Reward: 0005
# #579 Episode's Reward: 0000
# #580 Episode's Reward: 0012
# #581 Episode's Reward: -1465
# #582 Episode's Reward: -0411
# #583 Episode's Reward: 0000
# #584 Episode's Reward: -1953
# #585 Episode's Reward: 0000
# #586 Episode's Reward: 0004
# #587 Episode's Reward: -6928
# #588 Episode's Reward: -8994
# #589 Episode's Reward: -2541
# #590 Episode's Reward: -6727
# #591 Episode's Reward: 0000
# #592 Episode's Reward: 0004
# #593 Episode's Reward: -4932
# #594 Episode's Reward: 0000
# #595 Episode's Reward: 0036
# #596 Episode's Reward: 0000
# #597 Episode's Reward: 0006
# #598 Episode's Reward: 0000
# #599 Episode's Reward: 0012
# #600 Episode's Reward: -0306
# #601 Episode's Reward: -1715
# #602 Episode's Reward: 0006
# #603 Episode's Reward: 0001
# #604 Episode's Reward: -3381
# #605 Episode's Reward: -4974
# #606 Episode's Reward: 0002
# #607 Episode's Reward: 0004
# #608 Episode's Reward: 0004
# #609 Episode's Reward: -8107
# #610 Episode's Reward: 0000
# #611 Episode's Reward: 0000
# #612 Episode's Reward: 0000
# #613 Episode's Reward: -4040
# #614 Episode's Reward: -1427
# #615 Episode's Reward: 0000
# #616 Episode's Reward: 0009
# #617 Episode's Reward: 0000
# #618 Episode's Reward: 0000
# #619 Episode's Reward: 0000
# #620 Episode's Reward: -4626
# #621 Episode's Reward: 0000
# #622 Episode's Reward: -5582
# #623 Episode's Reward: 0013
# #624 Episode's Reward: -0653
# #625 Episode's Reward: 0019
# #626 Episode's Reward: 0008
# #627 Episode's Reward: 0000
# #628 Episode's Reward: 0007
# #629 Episode's Reward: -1054
# #630 Episode's Reward: 0000
# #631 Episode's Reward: 0010
# #632 Episode's Reward: 0001
# #633 Episode's Reward: -4151
# #634 Episode's Reward: -5689
# #635 Episode's Reward: 0000
# #636 Episode's Reward: -3105
# #637 Episode's Reward: 0005
# #638 Episode's Reward: 0000
# #639 Episode's Reward: -3282
# #640 Episode's Reward: -2895
# #641 Episode's Reward: 0000
# #642 Episode's Reward: 0000
# #643 Episode's Reward: -1565
# #644 Episode's Reward: -0827
# #645 Episode's Reward: 0000
# #646 Episode's Reward: 0000
# #647 Episode's Reward: -4124
# #648 Episode's Reward: -3934
# #649 Episode's Reward: 0006
# #650 Episode's Reward: -1619
# #651 Episode's Reward: 0000
# #652 Episode's Reward: 0000
# #653 Episode's Reward: 0015
# #654 Episode's Reward: -0938
# #655 Episode's Reward: 0000
# #656 Episode's Reward: -0356
# #657 Episode's Reward: -8696
# #658 Episode's Reward: 0004
# #659 Episode's Reward: -7210
# #660 Episode's Reward: -3150
# #661 Episode's Reward: 0005
# #662 Episode's Reward: 0000
# #663 Episode's Reward: 0000
# #664 Episode's Reward: -2918
# #665 Episode's Reward: 0006
# #666 Episode's Reward: -2895
# #667 Episode's Reward: 0001
# #668 Episode's Reward: -3113
# #669 Episode's Reward: -0080
# #670 Episode's Reward: -0429
# #671 Episode's Reward: -1484
# #672 Episode's Reward: 0001
# #673 Episode's Reward: -0960
# #674 Episode's Reward: -0704
# #675 Episode's Reward: 0015
# #676 Episode's Reward: 0000
# #677 Episode's Reward: -3119
# #678 Episode's Reward: -0895
# #679 Episode's Reward: -7019
# #680 Episode's Reward: -0618
# #681 Episode's Reward: 0006
# #682 Episode's Reward: 0001
# #683 Episode's Reward: -0702
# #684 Episode's Reward: 0000
# #685 Episode's Reward: -1329
# #686 Episode's Reward: 0000
# #687 Episode's Reward: -0542
# #688 Episode's Reward: 0000
# #689 Episode's Reward: 0000
# #690 Episode's Reward: -1045
# #691 Episode's Reward: 0000
# #692 Episode's Reward: 0000
# #693 Episode's Reward: -4223
# #694 Episode's Reward: -10021
# #695 Episode's Reward: -3444
# #696 Episode's Reward: 0008
# #697 Episode's Reward: -0299
# #698 Episode's Reward: 0000
# #699 Episode's Reward: -0906
# #700 Episode's Reward: -6179
# #701 Episode's Reward: -0640
# #702 Episode's Reward: 0012
# #703 Episode's Reward: 0000
# #704 Episode's Reward: 0000
# #705 Episode's Reward: -0064
# #706 Episode's Reward: 0000
# #707 Episode's Reward: -2946
# #708 Episode's Reward: 0005
# #709 Episode's Reward: 0000
# #710 Episode's Reward: 0000
# #711 Episode's Reward: 0000
# #712 Episode's Reward: 0000
# #713 Episode's Reward: 0000
# #714 Episode's Reward: 0000
# #715 Episode's Reward: 0000
# #716 Episode's Reward: -0415
# #717 Episode's Reward: 0000
# #718 Episode's Reward: 0033
# #719 Episode's Reward: 0000
# #720 Episode's Reward: 0001
# #721 Episode's Reward: 0000
# #722 Episode's Reward: -10815
# #723 Episode's Reward: 0000
# #724 Episode's Reward: 0040
# #725 Episode's Reward: 0040
# #726 Episode's Reward: -2224
# #727 Episode's Reward: -5465
# #728 Episode's Reward: 0000
# #729 Episode's Reward: -7115
# #730 Episode's Reward: 0000
# #731 Episode's Reward: -2214
# #732 Episode's Reward: 0002
# #733 Episode's Reward: 0000
# #734 Episode's Reward: 0000
# #735 Episode's Reward: 0000
# #736 Episode's Reward: 0000
# #737 Episode's Reward: 0000
# #738 Episode's Reward: 0000
# #739 Episode's Reward: -0109
# #740 Episode's Reward: 0000
# #741 Episode's Reward: 0009
# #742 Episode's Reward: 0000
# #743 Episode's Reward: 0000
# #744 Episode's Reward: 0000
# #745 Episode's Reward: 0000
# #746 Episode's Reward: 0000
# #747 Episode's Reward: 0000
# #748 Episode's Reward: -0625
# #749 Episode's Reward: 0000
# #750 Episode's Reward: -3105
# #751 Episode's Reward: 0000
# #752 Episode's Reward: 0010
# #753 Episode's Reward: -7410
# #754 Episode's Reward: 0000
# #755 Episode's Reward: 0000
# #756 Episode's Reward: 0010
# #757 Episode's Reward: 0000
# #758 Episode's Reward: 0000
# #759 Episode's Reward: 0000
# #760 Episode's Reward: 0003
# #761 Episode's Reward: -2539
# #762 Episode's Reward: 0000
# #763 Episode's Reward: 0001
# #764 Episode's Reward: 0007
# #765 Episode's Reward: -7403
# #766 Episode's Reward: 0000
# #767 Episode's Reward: 0000
# #768 Episode's Reward: 0000
# #769 Episode's Reward: -13220
# #770 Episode's Reward: -1780
# #771 Episode's Reward: 0000
# #772 Episode's Reward: -0129
# #773 Episode's Reward: 0000
# #774 Episode's Reward: 0000
# #775 Episode's Reward: 0000
# #776 Episode's Reward: 0000
# #777 Episode's Reward: -1164
# #778 Episode's Reward: 0000
# #779 Episode's Reward: 0000
# #780 Episode's Reward: -4465
# #781 Episode's Reward: 0000
# #782 Episode's Reward: 0000
# #783 Episode's Reward: 0000
# #784 Episode's Reward: -3260
# #785 Episode's Reward: 0003
# #786 Episode's Reward: 0000
# #787 Episode's Reward: 0000
# #788 Episode's Reward: 0000
# #789 Episode's Reward: 0000
# #790 Episode's Reward: 0000
# #791 Episode's Reward: 0000
# #792 Episode's Reward: 0000
# #793 Episode's Reward: -4380
# #794 Episode's Reward: 0000
# #795 Episode's Reward: 0000
# #796 Episode's Reward: 0000
# #797 Episode's Reward: 0000
# #798 Episode's Reward: -0351
# #799 Episode's Reward: 0000
# #800 Episode's Reward: 0000
# #801 Episode's Reward: 0000
# #802 Episode's Reward: -1799
# #803 Episode's Reward: -1512
# #804 Episode's Reward: 0017
# #805 Episode's Reward: 0000
# #806 Episode's Reward: 0000
# #807 Episode's Reward: 0000
# #808 Episode's Reward: 0005
# #809 Episode's Reward: 0002
# #810 Episode's Reward: 0000
# #811 Episode's Reward: 0017
# #812 Episode's Reward: 0000
# #813 Episode's Reward: 0000
# #814 Episode's Reward: 0000
# #815 Episode's Reward: 0012
# #816 Episode's Reward: -4304
# #817 Episode's Reward: 0000
# #818 Episode's Reward: 0000
# #819 Episode's Reward: -1189
# #820 Episode's Reward: -1524
# #821 Episode's Reward: 0000
# #822 Episode's Reward: 0000
# #823 Episode's Reward: 0000
# #824 Episode's Reward: 0000
# #825 Episode's Reward: 0003
# #826 Episode's Reward: 0000
# #827 Episode's Reward: 0000
# #828 Episode's Reward: -9595
# #829 Episode's Reward: 0000
# #830 Episode's Reward: 0000
# #831 Episode's Reward: 0000
# #832 Episode's Reward: -6489
# #833 Episode's Reward: 0000
# #834 Episode's Reward: 0005
# #835 Episode's Reward: -6215
# #836 Episode's Reward: -2355
# #837 Episode's Reward: -8210
# #838 Episode's Reward: 0000
# #839 Episode's Reward: -1889
# #840 Episode's Reward: -2974
# #841 Episode's Reward: 0000
# #842 Episode's Reward: 0000
# #843 Episode's Reward: 0000
# #844 Episode's Reward: 0000
# #845 Episode's Reward: 0000
# #846 Episode's Reward: 0000
# #847 Episode's Reward: 0000
# #848 Episode's Reward: 0000
# #849 Episode's Reward: 0000
# #850 Episode's Reward: 0000
# #851 Episode's Reward: 0000
# #852 Episode's Reward: -1049
# #853 Episode's Reward: 0000
# #854 Episode's Reward: 0000
# #855 Episode's Reward: 0000
# #856 Episode's Reward: -3765
# #857 Episode's Reward: 0000
# #858 Episode's Reward: 0000
# #859 Episode's Reward: 0000
# #860 Episode's Reward: 0000
# #861 Episode's Reward: 0004
# #862 Episode's Reward: -2109
# #863 Episode's Reward: 0000
# #864 Episode's Reward: 0000
# #865 Episode's Reward: 0003
# #866 Episode's Reward: 0000
# #867 Episode's Reward: 0006
# #868 Episode's Reward: 0000
# #869 Episode's Reward: 0000
# #870 Episode's Reward: -0930
# #871 Episode's Reward: 0000
# #872 Episode's Reward: 0000
# #873 Episode's Reward: 0000
# #874 Episode's Reward: -3815
# #875 Episode's Reward: 0003
# #876 Episode's Reward: 0000
# #877 Episode's Reward: 0004
# #878 Episode's Reward: 0001
# #879 Episode's Reward: -3609
# #880 Episode's Reward: 0000
# #881 Episode's Reward: 0007
# #882 Episode's Reward: 0000
# #883 Episode's Reward: 0000
# #884 Episode's Reward: 0000
# #885 Episode's Reward: 0000
# #886 Episode's Reward: 0000
# #887 Episode's Reward: 0000
# #888 Episode's Reward: 0000
# #889 Episode's Reward: 0000
# #890 Episode's Reward: 0000
# #891 Episode's Reward: 0000
# #892 Episode's Reward: 0000
# #893 Episode's Reward: 0000
# #894 Episode's Reward: 0000
# #895 Episode's Reward: 0000
# #896 Episode's Reward: 0000
# #897 Episode's Reward: 0000
# #898 Episode's Reward: 0000
# #899 Episode's Reward: 0000
# #900 Episode's Reward: 0000
# #901 Episode's Reward: -0334
# #902 Episode's Reward: 0000
# #903 Episode's Reward: -5265
# #904 Episode's Reward: 0009
# #905 Episode's Reward: 0000
# #906 Episode's Reward: 0000
# #907 Episode's Reward: 0000
# #908 Episode's Reward: 0000
# #909 Episode's Reward: 0000
# #910 Episode's Reward: -4199
# #911 Episode's Reward: 0000
# #912 Episode's Reward: 0000
# #913 Episode's Reward: 0000
# #914 Episode's Reward: 0000
# #915 Episode's Reward: 0000
# #916 Episode's Reward: 0000
# #917 Episode's Reward: -8210
# #918 Episode's Reward: 0000
# #919 Episode's Reward: 0000
# #920 Episode's Reward: 0000
# #921 Episode's Reward: 0000
# #922 Episode's Reward: 0000
# #923 Episode's Reward: 0000
# #924 Episode's Reward: 0000
# #925 Episode's Reward: 0000
# #926 Episode's Reward: 0000
# #927 Episode's Reward: 0000
# #928 Episode's Reward: 0000
# #929 Episode's Reward: 0000
# #930 Episode's Reward: 0000
# #931 Episode's Reward: 0000
# #932 Episode's Reward: 0000
# #933 Episode's Reward: 0000
# #934 Episode's Reward: 0000
# #935 Episode's Reward: 0000
# #936 Episode's Reward: 0000
# #937 Episode's Reward: 0000
# #938 Episode's Reward: 0000
# #939 Episode's Reward: 0000
# #940 Episode's Reward: 0000
# #941 Episode's Reward: -1555
# #942 Episode's Reward: 0000
# #943 Episode's Reward: 0000
# #944 Episode's Reward: 0000
# #945 Episode's Reward: 0000
# #946 Episode's Reward: 0000
# #947 Episode's Reward: 0000
# #948 Episode's Reward: 0000
# #949 Episode's Reward: 0002
# #950 Episode's Reward: 0000
# #951 Episode's Reward: 0000
# #952 Episode's Reward: 0000
# #953 Episode's Reward: 0000
# #954 Episode's Reward: -0824
# #955 Episode's Reward: 0000
# #956 Episode's Reward: 0000
# #957 Episode's Reward: -5102
# #958 Episode's Reward: -2439
# #959 Episode's Reward: 0000
# #960 Episode's Reward: 0000
# #961 Episode's Reward: 0000
# #962 Episode's Reward: 0000
# #963 Episode's Reward: 0000
# #964 Episode's Reward: 0000
# #965 Episode's Reward: 0000
# #966 Episode's Reward: 0005
# #967 Episode's Reward: 0000
# #968 Episode's Reward: 0001
# #969 Episode's Reward: 0000
# #970 Episode's Reward: 0004
# #971 Episode's Reward: 0002
# #972 Episode's Reward: 0001
# #973 Episode's Reward: 0000
# #974 Episode's Reward: 0000
# #975 Episode's Reward: 0000
# #976 Episode's Reward: 0000
# #977 Episode's Reward: 0000
# #978 Episode's Reward: 0000
# #979 Episode's Reward: 0002
# #980 Episode's Reward: 0002
# #981 Episode's Reward: 0000
# #982 Episode's Reward: 0000
# #983 Episode's Reward: -3525
# #984 Episode's Reward: 0000
# #985 Episode's Reward: 0000
# #986 Episode's Reward: 0001
# #987 Episode's Reward: -2859
# #988 Episode's Reward: 0000
# #989 Episode's Reward: 0013
# #990 Episode's Reward: 0000
# #991 Episode's Reward: 0000
# #992 Episode's Reward: 0000
# #993 Episode's Reward: 0000
# #994 Episode's Reward: -2389
# #995 Episode's Reward: 0002
# #996 Episode's Reward: 0000
# #997 Episode's Reward: 0000
# #998 Episode's Reward: -0380
# #999 Episode's Reward: 0000
